# %%
from datasets import load_dataset
import pandas as pd
from IPython.display import display

# Load the dataset
dataset = load_dataset("paraloq/json_data_extraction")

# Convert the 'train' split to a Pandas DataFrame
df = pd.DataFrame(dataset['train'])

# Display the first few rows as a table
display(df.head())

# Optional: Render specific columns if needed
display(df[['topic', 'schema', 'item']].head())
# Out:
#                          title    topic                    item_id  \
# 0      Prescription Medication  medical     PrescriptionMedication
# 1         Medical Test Results  medical         MedicalTestResults
# 2          Medical Appointment  medical         MedicalAppointment
# 3      Patient Medical History  medical      PatientMedicalHistory
# 4  Pharmacy Prescription Order  medical  PharmacyPrescriptionOrder
#
#                                               schema  \
# 0  {"$schema": "http://json-schema.org/draft-07/s...
# 1  {"$schema": "http://json-schema.org/draft-07/s...
# 2  {"$schema": "http://json-schema.org/draft-07/s...
# 3  {"$schema": "http://json-schema.org/draft-07/s...
# 4  {"$schema": "http://json-schema.org/draft-07/s...
#
#                                                 item  \
# 0  {"prescription": {"prescriptionId": "RX123456"...
# 1  {"MedicalTestResults": [{"testId": "MT12345", ...
# 2  {"appointment": {"id": "9316b131-d808-484e-9d5...
# 3  {"patientId": "1234567890", "name": "Jane Doe"...
# 4  {"patient": {"firstName": "Aiden", "lastName":...
#
#                                                 text            medium  \
# 0  **Medical Document**\n\n**Patient Information*...  medical document
# 1  **Medical Document**\n\n**Patient:** John Doe\...  medical document
# 2  **Medical Record**\n\n**Patient Information**\...  medical document
# 3  **Medical Record**\n\n**Patient Information**\...  medical document
# 4  **Medical Record**\n\n**Patient Information**\...  medical document
#
#    __index_level_0__
# 0                  1
# 1                  2
# 2                  4
# 3                  5
# 4                  6
#      topic                                             schema  \
# 0  medical  {"$schema": "http://json-schema.org/draft-07/s...
# 1  medical  {"$schema": "http://json-schema.org/draft-07/s...
# 2  medical  {"$schema": "http://json-schema.org/draft-07/s...
# 3  medical  {"$schema": "http://json-schema.org/draft-07/s...
# 4  medical  {"$schema": "http://json-schema.org/draft-07/s...
#
#                                                 item
# 0  {"prescription": {"prescriptionId": "RX123456"...
# 1  {"MedicalTestResults": [{"testId": "MT12345", ...
# 2  {"appointment": {"id": "9316b131-d808-484e-9d5...
# 3  {"patientId": "1234567890", "name": "Jane Doe"...
# 4  {"patient": {"firstName": "Aiden", "lastName":...
